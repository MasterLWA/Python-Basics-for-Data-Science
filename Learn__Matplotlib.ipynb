# %% [markdown]
# <a href="https://colab.research.google.com/github/MasterLWA/Python-Basics-for-Data-Science/blob/main/Learn__Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplotlib is a library used to create graphs, charts, and figures. It also provides functions to customize your figures by changing the colors, labels, etc.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# * The .plot() function is used to create a plot from the data in a Pandas Series or DataFrame.
# * plt.savefig('plot.png') is used to save and display the chart

# %%
s = pd.Series([18, 42, 9, 32, 81, 64, 3])

s.plot(kind='bar')
plt.savefig('plot.png')

# %% [markdown]
# Imported dataset

# %%
df = pd.read_csv("https://www.sololearn.com/uploads/ca-covid.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    342 non-null    object
#  1   state   342 non-null    object
#  2   cases   342 non-null    int64
#  3   deaths  342 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 10.8+ KB

# %% [markdown]
# # line graph

# %%
df[['deaths', 'cases']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Bar Plot
# *   The plot() function can take a kind argument
# *   plot(kind="bar") to generate Bargraph

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df['date'] = pd.to_datetime(df['date'], format="%d.%m.%y") #genarate date column
df['month'] = df['date'].dt.month #genarate month column using date column

# %%
(df.groupby('month')['cases'].sum()).plot(kind="bar")
plt.savefig('plot.png')

# %%
df = df.groupby('month')[['cases', 'deaths']].sum()
df.plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='month'>

# %%
df.plot(kind="barh", stacked=True) #kind="barh" can be used to create a horizontal bar chart
# Out:
# <Axes: ylabel='month'>

# %% [markdown]
# # Box Plot

# %%
df = pd.read_csv("https://www.sololearn.com/uploads/ca-covid.csv")
df.drop('state', axis=1, inplace=True)

df['date'] = pd.to_datetime(df['date'], format="%d.%m.%y")
df['month'] = df['date'].dt.month
df.set_index('date', inplace=True)

df[df["month"]==6]["cases"].plot(kind="box")
plt.savefig('plot.png')

# %% [markdown]
# * The green line shows the median value.
# * The box shows the upper and lower quartiles (25% of the data is greater or less than these values).
# * The circles show the outliers, while the black lines show the min/max values excluding the outliers.

# %%
df[df["month"]==6]["cases"].plot(kind="hist") #histogram
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Area Plot

# %%
df[df["month"]==6][["cases", "deaths"]].plot(kind="area", stacked=False)
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# * kind='area' creates an Area plot
# * Area plots are stacked by default, which is why we provided stacked=False explicitly.

# %% [markdown]
# # Scatter plot
# * A scatter plot is used to show the relationship between two variables.

# %%
df[df["month"]==6][["cases", "deaths"]].plot(kind="scatter", x='cases', y='deaths')
# Out:
# <Axes: xlabel='cases', ylabel='deaths'>

# %% [markdown]
# **Pie Chart**

# %%
df.groupby('month')['cases'].sum().plot(kind="pie")
# Out:
# <Axes: ylabel='cases'>

# %% [markdown]
# * The legend argument specifies whether or not to show the legend.
# * You can also change the labels of the axis by setting the xlabel and ylabel arguments.
# * The suptitle() function can be used to set a plot title.

# %%
df[['cases', 'deaths']].plot(kind="line", legend=True)
plt.xlabel('Days in June')
plt.ylabel('Number')
plt.suptitle("COVID-19 in June")
# Out:
# Text(0, 0.5, 'Number')

# %%
df[['cases', 'deaths']].plot(kind="area",
   legend=True,
   stacked=False,
   color=['#1970E7', '#E73E19']) #add colors to the ghraph
plt.suptitle('Covid-19')
# Out:
# Text(0.5, 0.98, 'Covid-19')

# %%
data = {
'sport': ["Soccer", "Tennis", "Soccer", "Hockey"],
'players': [5, 4, 8, 20]
}
df = pd.DataFrame(data)
df.groupby('sport')['players'].sum().plot(kind="pie")
# Out:
# <Axes: ylabel='players'>
